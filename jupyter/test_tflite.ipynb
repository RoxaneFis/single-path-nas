# %%
from tensorflow.python.estimator import estimator
import tensorflow as tf
from tensorflow.core.protobuf import rewriter_config_pb2
from tensorflow.python.estimator import estimator
from tensorflow.python.keras import backend as K

# %%
# !pip show tensorflow
# Out:
# Name: tensorflow
# Version: 1.12.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: opensource@google.com
# License: Apache 2.0
# Location: /Users/roxanefischer/miniconda3/envs/nas/lib/python3.6/site-packages
# Requires: termcolor, astor, absl-py, gast, grpcio, numpy, keras-preprocessing, keras-applications, protobuf, six, tensorboard, wheel
# Required-by:

# %% [markdown]
# # Load model - Error

# %%
pbPath='/Users/roxanefischer/Documents/cours/3A/Stage_ML/single-path-nas/models/tiny_tiny_imagenet/export_dir/1587558651'
'''
converter = tf.lite.TFLiteConverter.from_saved_model(
    pbPath)
'''
converter = tf.contrib.lite.TFLiteConverter.from_saved_model(
    pbPath,
    input_arrays=['truediv'],
    output_arrays=['logits'])


tflite_model = converter.convert()
open(tflitePath, "wb").write(tflite_model)
# Out:
# INFO:tensorflow:Restoring parameters from /Users/roxanefischer/Documents/cours/3A/Stage_ML/single-path-nas/models/tiny_tiny_imagenet/export_dir/1587558651/variables/variables
# INFO:tensorflow:The given SavedModel MetaGraphDef contains SignatureDefs with the following keys: {'classify', 'serving_default'}
# INFO:tensorflow:input tensors info:
# INFO:tensorflow:Tensor's key in saved_model's tensor_map: images
# INFO:tensorflow: tensor name: Placeholder:0, shape: (1, 64, 64, 3), type: DT_FLOAT
# INFO:tensorflow:output tensors info:
# INFO:tensorflow:Tensor's key in saved_model's tensor_map: probabilities
# INFO:tensorflow: tensor name: softmax_tensor:0, shape: (1, 200), type: DT_FLOAT
# INFO:tensorflow:Tensor's key in saved_model's tensor_map: classes
# INFO:tensorflow: tensor name: ArgMax:0, shape: (1), type: DT_INT64
# ...
